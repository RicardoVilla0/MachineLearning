# %% [markdown]
# <a href="https://colab.research.google.com/github/RicardoVilla0/MachineLearning/blob/main/Unidad%202/practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Asignatura: Machine Learning
#
# Unidad 2
#
# Docente: Jose Gabriel Rodriguez Rivas
#
# Alumno: Ochoa Villa Ricardo Aron
#
# Practica 1: Evaluar Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('autos2.csv')
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    peak-rpm  city-mpg  highway-L/100km    price city-L/100km fuel-type_code  \
# ...

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %%
X = df[['highway-L/100km']]
Y = df[['price']]

# %%
lm.fit(X, Y)
# Out:
# LinearRegression()

# %%
Yhat = lm.predict(X)
Yhat[0:5]
# Out:
# array([[15485.52737455],
#        [15485.52737455],
#        [16643.34931414],
#        [12475.19033163],
#        [22327.2024721 ]])

# %%
lm.intercept_
# Out:
# array([-14617.84305466])

# %%
lm.coef_
# Out:
# array([[3458.68511314]])

# %%
Yhat = - 821.71316345 * 30 + 38581.394060408405
Yhat
# Out:
# 13929.999156908405

# %%
valores = [[30]]
Yhat = lm.predict(valores)
Yhat
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[89142.71033965]])

# %%
valores = [[30], [20], [40], [18], [30], [15]]
Yhat = lm.predict(valores)
Yhat
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 89142.71033965],
#        [ 54555.85920821],
#        [123729.56147109],
#        [ 47638.48898192],
#        [ 89142.71033965],
#        [ 37262.43364249]])

# %%
lm.score (X, Y)
# Out:
# 0.6417894513258818

# %%
lm1 = LinearRegression()
lm1
# Out:
# LinearRegression()

# %%
lm1.fit(df[['engine-size']], df[['price']])
lm1
# Out:
# LinearRegression()

# %%
lm1.coef_
# Out:
# array([[166.86001569]])

# %%
lm1.intercept_
# Out:
# array([-7963.33890628])

# %%
yhat1 = lm1.predict(df[['engine-size']])
yhat1
# Out:
# array([[13728.4631336 ],
#        [13728.4631336 ],
#        [17399.38347881],
#        [10224.40280408],
#        [14729.62322775],
#        [14729.62322775],
#        [14729.62322775],
#        [14729.62322775],
#        [13895.32314929],
#        [10057.54278839],
#        [10057.54278839],
#        [19401.70366711],
#        [19401.70366711],
#        [19401.70366711],
#        [26910.40437322],
#        [26910.40437322],
#        [26910.40437322],
#        [ 2215.1220509 ],
#        [ 7054.06250595],
#        [ 7054.06250595],
#        [ 7054.06250595],
#        [ 7054.06250595],
#        [ 8388.94263148],
#        [ 7054.06250595],
#        [ 7054.06250595],
#        [ 7054.06250595],
#        [ 8388.94263148],
#        [12393.58300807],
#        [18066.82354158],
#        [ 7387.78253733],
#        [ 7387.78253733],
#        [ 5218.60233334],
#        [ 7387.78253733],
#        [ 7387.78253733],
#        [ 7387.78253733],
#        [ 7387.78253733],
#        [10391.26281977],
# ...

# %%
lm1.predict([[120]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[12059.86297669]])

# %%
lm1.score(df[['engine-size']], df[['price']])
# Out:
# 0.7609686443622008

# %%
df[["engine-size", "highway-L/100km","price"]].corr()
# Out:
#                  engine-size  highway-L/100km     price
# engine-size         1.000000         0.783465  0.872335
# highway-L/100km     0.783465         1.000000  0.801118
# price               0.872335         0.801118  1.000000

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-L/100km']]

# %%
lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# np.float64(-14385.634549360107)

# %%
lm.coef_
# Out:
# array([ 36.6377371 ,   3.50038215,  85.37370862, 500.51979785])

# %%
yhat2 = 36.6377371 * 120 + 3.50038215 * 2600 + 85.37370862 * 135 + 500.51979785 * 25 -14385.634549360107
yhat2
# Out:
# 23150.33310258989

# %%
valores = [[120, 2600, 135, 25],[135,2500, 123, 28]]
yhat2 = lm.predict(valores)
yhat2
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23150.33310299, 23826.93583453])

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-L/100km", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47719.66663397575)

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %%
lm3 = LinearRegression()
lm3
X3.head()
Yhat3=lm3.predict(X3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4177583483.py in <cell line: 0>()
#       1 lm3 = LinearRegression()
#       2 lm3
# ----> 3 Yhat3=lm3.predict(X3)
#
# NameError: name 'X3' is not defined

# %%
lm3 = LinearRegression()
lm3
lm3.fit(df[[["engine-size","price"]]])
Yhat3=lm3.predict(X3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2491853349.py in <cell line: 0>()
#       1 lm3 = LinearRegression()
#       2 lm3
# ----> 3 lm3.fit(df[[["engine-size","price"]]])
#       4 Yhat3=lm3.predict(X3)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
# ...

# %%
plt.figure(figsize=(8, 6))
ax1 = sns.kdeplot(df['price'], color="r", label="Actual Value")
ax1 = sns.kdeplot(yhat2, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')
plt.legend()
plt.show()
plt.close()
